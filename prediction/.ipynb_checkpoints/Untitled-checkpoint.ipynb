# %%
import os
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Paths to Synthea CSVs (ensure these match your actual structure)
DATA_DIR = "../data/raw/"
PROCESSED_DATA_DIR = "../data//processed/"

# %%
patients = pd.read_csv(os.path.join(DATA_DIR, "patients.csv"))
conditions = pd.read_csv(os.path.join(DATA_DIR, "conditions.csv"))
medications = pd.read_csv(os.path.join(DATA_DIR, "medications.csv"))
encounters = pd.read_csv(os.path.join(DATA_DIR, "encounters.csv"))

# %%
for file in [
    "patients.csv",
    "conditions.csv",
    "medications.csv",
    "encounters.csv",
    "observations.csv",
]:
    print(f"\n{file} columns:")
    print(pd.read_csv(f"../data/raw/{file}").columns.tolist())
# Out:
# patients.csv columns:
# ['Id', 'BIRTHDATE', 'DEATHDATE', 'SSN', 'DRIVERS', 'PASSPORT', 'PREFIX', 'FIRST', 'LAST', 'SUFFIX', 'MAIDEN', 'MARITAL', 'RACE', 'ETHNICITY', 'GENDER', 'BIRTHPLACE', 'ADDRESS', 'CITY', 'STATE', 'COUNTY', 'ZIP', 'LAT', 'LON', 'HEALTHCARE_EXPENSES', 'HEALTHCARE_COVERAGE']
#
# conditions.csv columns:
# ['START', 'STOP', 'PATIENT', 'ENCOUNTER', 'CODE', 'DESCRIPTION']
#
# medications.csv columns:
# ['START', 'STOP', 'PATIENT', 'PAYER', 'ENCOUNTER', 'CODE', 'DESCRIPTION', 'BASE_COST', 'PAYER_COVERAGE', 'DISPENSES', 'TOTALCOST', 'REASONCODE', 'REASONDESCRIPTION']
#
# encounters.csv columns:
# ['Id', 'START', 'STOP', 'PATIENT', 'ORGANIZATION', 'PROVIDER', 'PAYER', 'ENCOUNTERCLASS', 'CODE', 'DESCRIPTION', 'BASE_ENCOUNTER_COST', 'TOTAL_CLAIM_COST', 'PAYER_COVERAGE', 'REASONCODE', 'REASONDESCRIPTION']
#
# observations.csv columns:
# ['DATE', 'PATIENT', 'ENCOUNTER', 'CATEGORY', 'CODE', 'DESCRIPTION', 'VALUE', 'UNITS', 'TYPE']

# %%
# Convert relevant columns to datetime
encounters["START"] = pd.to_datetime(encounters["START"], errors="coerce")
patients["DEATHDATE"] = pd.to_datetime(patients["DEATHDATE"], errors="coerce")
patients["BIRTHDATE"] = pd.to_datetime(patients["BIRTHDATE"], errors="coerce")
medications["BASE_COST"] = pd.to_numeric(medications["BASE_COST"], errors="coerce")
medications["TOTALCOST"] = pd.to_numeric(medications["TOTALCOST"], errors="coerce")
encounters["BASE_ENCOUNTER_COST"] = pd.to_numeric(
    encounters["BASE_ENCOUNTER_COST"], errors="coerce"
)

# %% [markdown]
# # FEATURE ENGINEERING

# %%
# Age, gender, race, marital, ethnicity
patients["age"] = 2025 - patients["BIRTHDATE"].dt.year
patients["death_flag"] = patients["DEATHDATE"].notna().astype(int)
patients = patients.rename(
    columns={
        "Id": "patient",
        "GENDER": "gender",
        "MARITAL": "marital_status",
        "RACE": "race",
        "ETHNICITY": "ethnicity",
    }
)
patient_df = patients[
    ["patient", "gender", "age", "marital_status", "race", "ethnicity", "death_flag"]
]

# %%
patient_df.head()
# Out:
#                                 patient gender  age marital_status   race  \
# 0  f4db39b1-693d-e301-0a1f-41d26d3ced36      M   40              S  white
# 1  e8503522-82ff-67a2-4dad-29281d6318de      M   60              M  white
# 2  ac643af6-1a32-08ce-df40-1c31348bcb41      M   60              M  white
# 3  358f26b9-a982-0346-55d3-65e8667f39e9      F   71              S  white
# 4  1017741e-00f0-e3dc-5c93-f5b0053f2cc4      M   71              M  white
#
#      ethnicity  death_flag
# 0  nonhispanic           0
# 1  nonhispanic           0
# 2  nonhispanic           0
# 3     hispanic           0
# 4  nonhispanic           0

# %%
# Number of encounters and average cost
encounter_features = (
    encounters.groupby("PATIENT")
    .agg(
        num_encounters=("Id", "count"),
        recent_encounter_type=(
            "ENCOUNTERCLASS",
            lambda x: x.iloc[-1] if len(x) > 0 else None,
        ),
        avg_encounter_cost=("BASE_ENCOUNTER_COST", "mean"),
    )
    .reset_index()
    .rename(columns={"PATIENT": "patient"})
)

# %%
encounter_features
# Out:
#                                   patient  num_encounters  \
# 0    096aae79-612c-c566-d14b-ca23b5595cdb             141
# 1    1017741e-00f0-e3dc-5c93-f5b0053f2cc4              56
# 2    10182af0-da35-e957-8a8f-36ad80ae3191              51
# 3    144396bf-ca8b-5aa6-2511-4a9bb8fe1ef5             107
# 4    15a351f5-ada6-1fc3-dfd2-7af42d1731b2              59
# ..                                    ...             ...
# 135  f2db174c-fb9d-3408-8bf4-8bff7826d2f1             136
# 136  f4db39b1-693d-e301-0a1f-41d26d3ced36              55
# 137  f7019a56-1940-b131-f5e2-39439c16a942             112
# 138  f7f39409-b7b4-224d-6354-2acd6f94f2f8              54
# 139  fc88755b-6767-bfb6-aa78-584a66b8a139              35
#
#     recent_encounter_type  avg_encounter_cost
# 0                wellness          117.848511
# 1                wellness          111.548929
# 2              ambulatory          132.966863
# 3                wellness          125.001028
# 4                wellness          130.083390
# ..                    ...                 ...
# 135              wellness          129.510074
# 136            outpatient          100.247455
# 137            ambulatory          125.528929
# 138              wellness          108.140741
# 139              wellness          129.911714
#
# [140 rows x 4 columns]

# %%
encounters.head()
# Out:
#                                      Id                     START  \
# 0  fa301d15-4761-7c57-6633-5c81cc43d233 1997-11-02 15:42:51+00:00
# 1  9d4fb2ca-abbd-4270-822a-880cfc94bfb0 1999-11-16 15:42:51+00:00
# 2  acde7c73-fba1-be42-58ad-314c7c6465a2 2000-02-24 15:42:51+00:00
# 3  aaf60ab9-3f5e-2ff1-8300-a2dbdacb04ce 2000-05-01 15:42:51+00:00
# 4  96e42627-d0ab-7e1a-30dc-0731aa49151f 2000-11-19 15:42:51+00:00
#
#                    STOP                               PATIENT  \
# 0  1997-11-02T15:57:51Z  f4db39b1-693d-e301-0a1f-41d26d3ced36
# 1  1999-11-17T15:42:51Z  f4db39b1-693d-e301-0a1f-41d26d3ced36
# 2  2000-02-25T15:42:51Z  f4db39b1-693d-e301-0a1f-41d26d3ced36
# 3  2000-05-02T15:42:51Z  f4db39b1-693d-e301-0a1f-41d26d3ced36
# 4  2000-11-19T15:57:51Z  f4db39b1-693d-e301-0a1f-41d26d3ced36
#
#                            ORGANIZATION                              PROVIDER  \
# 0  1977f8c2-6ece-3f46-8c60-b5961bb867a9  4d12f6b0-c28e-348d-975f-25a388ef89ee
# 1  a0b6ec0c-e587-3b2a-bf9f-248849f29ee5  72e3edc9-9294-33d5-b927-49c56433871d
# 2  a0b6ec0c-e587-3b2a-bf9f-248849f29ee5  72e3edc9-9294-33d5-b927-49c56433871d
# 3  a0b6ec0c-e587-3b2a-bf9f-248849f29ee5  72e3edc9-9294-33d5-b927-49c56433871d
# 4  1977f8c2-6ece-3f46-8c60-b5961bb867a9  4d12f6b0-c28e-348d-975f-25a388ef89ee
#
#                                   PAYER ENCOUNTERCLASS       CODE  \
# 0  4d71f845-a6a9-3c39-b242-14d25ef86a8d       wellness  410620009
# 1  d47b3510-2895-3b70-9897-342d681c769d      inpatient  183452005
# 2  d47b3510-2895-3b70-9897-342d681c769d      inpatient  183452005
# 3  d47b3510-2895-3b70-9897-342d681c769d      inpatient  183452005
# 4  4d71f845-a6a9-3c39-b242-14d25ef86a8d       wellness  410620009
#
#                     DESCRIPTION  BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  \
# 0  Well child visit (procedure)               136.80           1329.88
# 1           Encounter Inpatient                87.71            615.64
# 2           Encounter Inpatient                87.71            711.67
# 3           Encounter Inpatient                87.71           9237.66
# 4  Well child visit (procedure)               136.80            704.20
#
#    PAYER_COVERAGE    REASONCODE                          REASONDESCRIPTION
# 0             0.0           NaN                                        NaN
# 1             0.0  1.241710e+14  Chronic intractable migraine without aura
# 2             0.0  8.242300e+07                               Chronic pain
# 3             0.0  1.964160e+08                            Impacted molars
# 4             0.0           NaN                                        NaN

# %%
# Simulate readmission label (30-day rule)
readmit_flags = []
for patient_id in patients["patient"]:
    dates = sorted(encounters[encounters["PATIENT"] == patient_id]["START"])
    readmitted = 0
    for i in range(1, len(dates)):
        if (dates[i] - dates[i - 1]) <= timedelta(days=30):
            readmitted = 1
            break
    readmit_flags.append(
        {"patient": patient_id, "readmitted": readmitted, "date": dates[i]}
    )
readmit_df = pd.DataFrame(readmit_flags)

# %%
readmit_df.head()
# Out:
#                                 patient  readmitted                      date
# 0  f4db39b1-693d-e301-0a1f-41d26d3ced36           1 2013-01-08 16:16:09+00:00
# 1  e8503522-82ff-67a2-4dad-29281d6318de           1 1983-12-31 15:50:45+00:00
# 2  ac643af6-1a32-08ce-df40-1c31348bcb41           1 1967-04-06 18:27:19+00:00
# 3  358f26b9-a982-0346-55d3-65e8667f39e9           1 2013-01-15 17:44:07+00:00
# 4  1017741e-00f0-e3dc-5c93-f5b0053f2cc4           1 2004-01-26 23:01:30+00:00

# %%
sns.countplot(x="readmitted", data=readmit_df)
# Out:
# <Axes: xlabel='readmitted', ylabel='count'>

# %%
# Conditions: count and chronic flag (e.g., diabetes, COPD, asthma)
chronic_keywords = ["diabetes", "copd", "asthma", "hypertension", "chronic"]
conditions["is_chronic"] = (
    conditions["DESCRIPTION"]
    .str.lower()
    .apply(lambda x: any(keyword in x for keyword in chronic_keywords))
)
cond_features = (
    conditions.groupby("PATIENT")
    .agg(
        num_conditions=("DESCRIPTION", "count"),
        chronic_disease_flag=("is_chronic", "max"),
    )
    .reset_index()
    .rename(columns={"PATIENT": "patient"})
)

# %%
# Medications: count and costs
med_features = (
    medications.groupby("PATIENT")
    .agg(
        num_medications=("DESCRIPTION", "count"),
        avg_med_cost=("BASE_COST", "mean"),
        total_med_cost=("TOTALCOST", "sum"),
    )
    .reset_index()
    .rename(columns={"PATIENT": "patient"})
)

# %%
# ==== Final Merge ====
df = (
    patient_df.merge(encounter_features, on="patient", how="left")
    .merge(cond_features, on="patient", how="left")
    .merge(med_features, on="patient", how="left")
    .merge(readmit_df, on="patient", how="left")
)

# %%
df.head()
# Out:
#                                 patient gender  age marital_status   race  \
# 0  f4db39b1-693d-e301-0a1f-41d26d3ced36      M   40              S  white
# 1  e8503522-82ff-67a2-4dad-29281d6318de      M   60              M  white
# 2  ac643af6-1a32-08ce-df40-1c31348bcb41      M   60              M  white
# 3  358f26b9-a982-0346-55d3-65e8667f39e9      F   71              S  white
# 4  1017741e-00f0-e3dc-5c93-f5b0053f2cc4      M   71              M  white
#
#      ethnicity  death_flag  num_encounters recent_encounter_type  \
# 0  nonhispanic           0              55            outpatient
# 1  nonhispanic           0              63              wellness
# 2  nonhispanic           0              52              wellness
# 3     hispanic           0              72              wellness
# 4  nonhispanic           0              56              wellness
#
#    avg_encounter_cost  num_conditions  chronic_disease_flag  num_medications  \
# 0          100.247455              21                  True             11.0
# 1          120.049048              61                  True            146.0
# 2          127.526923              53                  True             43.0
# 3          128.202083              37                  True             13.0
# 4          111.548929              47                  True             20.0
#
#    avg_med_cost  total_med_cost  readmitted                      date
# 0    498.663636         6279.27           1 2013-01-08 16:16:09+00:00
# 1      0.717466         2243.87           1 1983-12-31 15:50:45+00:00
# 2      0.425814          166.38           1 1967-04-06 18:27:19+00:00
# 3    250.130769        22400.91           1 2013-01-15 17:44:07+00:00
# 4      0.199000            6.05           1 2004-01-26 23:01:30+00:00

# %%
df[df["date"] > "2025-01-08 16:16:09+00:00"]

# %%
# sns.histplot(df[df["date"] > "2013-01-08 16:16:09+00:00"])

# %%
df.isnull().sum()

# %%
# Fill NAs
df["num_encounters"] = df["num_encounters"].fillna(0).astype(int)
df["avg_encounter_cost"] = df["avg_encounter_cost"].fillna(0)
df["num_conditions"] = df["num_conditions"].fillna(0).astype(int)
df["chronic_disease_flag"] = df["chronic_disease_flag"].fillna(0).astype(int)
df["num_medications"] = df["num_medications"].fillna(0).astype(int)
df["avg_med_cost"] = df["avg_med_cost"].fillna(0)
df["total_med_cost"] = df["total_med_cost"].fillna(0)
df["readmitted"] = df["readmitted"].fillna(0).astype(int)

# %%
# Save to file
os.makedirs(PROCESSED_DATA_DIR, exist_ok=True)
df.to_csv(f"{PROCESSED_DATA_DIR}/training_data.csv", index=False)
print(f"✅ Final training dataset saved to '{PROCESSED_DATA_DIR}/training_data.csv'")
